# %%
import requests
import bs4
import pandas as pd

# %%
url_base = 'https://www.cars.com/for-sale/searchresults.action/?page=1&perPage=100&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true'
response = requests.get(url_base)
html = bs4.BeautifulSoup(response.text, "lxml")

# %%
def grab_data_from_given_url(url, lst):
    response = requests.get(url)
    html = bs4.BeautifulSoup(response.text, "lxml")
    tmp_lst = html.find_all("div", id = "srp-listing-rows-container")
    if(len(tmp_lst) == 0):
        print('Cannot search page: ' + url)
        return
    container = html.find_all("div", id = "srp-listing-rows-container")[0]
    for child in container.children:
        car = {}
        if type(child) is not bs4.element.NavigableString and child.name == 'div':
            if child.has_attr('class') and child.a:
                if child.a and child.a.div:
                    for ch in child.a.div.children:
                        if type(ch) is bs4.element.Tag and ch.has_attr('class') and ch['class'][0] == 'listing-row__details':
                            car['Name'] = ch.h2.text.strip()
                            for item in ch.find_all('span'):
                                if type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__mileage':
                                    car['Mileage'] = item.text.strip()
                                elif type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__price':
                                    car['Price'] = item.text.strip()
                else:
                    print('Cannot search page: ' + url)
                    return 
                        
        if len(car) > 0:
            lst.append(car)

# %%
url_base = 'https://www.cars.com/for-sale/searchresults.action/?page=1&perPage=20&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true'
url_head = 'https://www.cars.com/for-sale/searchresults.action/?'
url_tail = '&perPage=100&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true'

brand_dict = {}

def generate_brand_keys():
    response = requests.get(url_base)
    html = bs4.BeautifulSoup(response.text, "lxml")
    make_lst = html.find_all('input', attrs={"name": "mkId"})
    for brand in make_lst:
        
        brand_name = brand.parent.label.text.strip()
        mkid = brand['value']
        brand_dict[brand_name] = mkid
        
generate_brand_keys()

# %%
def generate_model_keys(url_tmp, dic):
    response = requests.get(url_tmp)
    html = bs4.BeautifulSoup(response.text, "lxml")
    md_lst = html.find_all('input', attrs={"name": "mdId"})
    for md in md_lst:
        
        md_name = md.parent.label.text.strip()
        mdid = md['value']
        dic[md_name] = mdid

# brand_already_searched = ['AC', 'Acura', 'Alfa Romeo', 'Am General', \
#                           'American Motors', 'Aston Martin', 'Audi', 'Austin-Healey', \
#                           'Avanti Motors', 'BMW', 'Bentley', 'Bricklin', 'Bugatti', 'Buick', \
#                           'Cadillac', 'Chevrolet', 'Chrysler', 'Citroen', 'Daewoo', 'Datsun', \
#                           'DeTomaso', 'Delorean', 'Dodge', 'Eagle', 'Edsel', 'FIAT', 'Ferrari', \
#                           'Fisker', 'Ford', 'GMC', 'Genesis', 'Geo', 'Honda', 'Hudson', 'Hummer', \
#                           'Hyundai', 'INFINITI', 'International', 'Isuzu', 'Jaguar', \
#                           'Mercedes-Benz', 'McLaren', 'Mazda', 'Maybach', 'Maserati', 'MINI', \
#                           'MG', 'Lotus', 'Lincoln', 'Lexus', 'Land Rover', 'Lamborghini', 'Koenigsegg', \
#                           'Jensen', 'Karma', 'Kia', 'Jeep', 'Mercury', 'Mitsubishi', 'Morris', 'Nash']

# %%
def launch_search_given_id(url, lst, make_id, md_id):
    response = requests.get(url)
    html = bs4.BeautifulSoup(response.text, "lxml")
    lst_tmp = html.find_all('span', attrs={'class':"count"})
    if len(lst_tmp) == 0:
        print('Cannot search page: ' + url)
        return
    found_count = int(lst_tmp[0].text.replace(',', ''))
    num_of_pages = found_count//100 + 1
    for page_num in range(1, num_of_pages + 1):
        if (md_id == ''):
            grab_data_from_given_url(url_head + 'mkId=' + make_id + "&" + "page=" \
                                         + str(page_num) + url_tail, lst)
        else:
            grab_data_from_given_url(url_head + "mdId=" + md_id + "&" + 'mkId=' + make_id + "&" + "page=" \
                                         + str(page_num) + url_tail, lst)

def launch_search():
    for brand in brand_dict:
        #Launch search before Nissan
        if brand == 'Nissan':
            break
        print("Now searching: " + brand)
        make_id = brand_dict[brand]
        url_tmp = url_head + 'mkId=' + make_id + "&" + "page=1" + url_tail
        response = requests.get(url_tmp)
        html = bs4.BeautifulSoup(response.text, "lxml")

        # See how many cars we found.
        found_count = int(html.find_all('span', attrs={'class':"count"})[0].text.replace(',', ''))
        
        # If less then 5000, start the search right now
        if found_count <= 5000:
            list_of_cars = []
            md_id = ''
            launch_search_given_id(url_tmp, list_of_cars, make_id, md_id)
            df_car = pd.DataFrame(list_of_cars, columns=['Name', 'Mileage', 'Price'])
            file_name = '(New)' + brand + '.csv'
            file_name = file_name.replace('/', ' ')
            df_car.to_csv(file_name)
        else:
            md_dict = {}
            generate_model_keys(url_tmp, md_dict)
            
            for md in md_dict:
                print("Now searching model: " + md)
                md_id = md_dict[md]
                url_tmp = url_head + "mdId=" + md_id + "&" + 'mkId=' + make_id + "&" + "page=1" + url_tail
                response = requests.get(url_tmp)
                html = bs4.BeautifulSoup(response.text, "lxml")
                list_of_cars = []
                launch_search_given_id(url_tmp, list_of_cars, make_id, md_id)
                df_car = pd.DataFrame(list_of_cars, columns=['Name', 'Mileage', 'Price'])
                file_name = '(New)' + brand + "-" + md + '.csv'
                file_name = file_name.replace('/', ' ')
                df_car.to_csv(file_name)

# %%
launch_search()
# Out:
# Now searching: AC
# Now searching: Acura
# Now searching model: CL
# Now searching model: ILX
# Now searching model: ILX Hybrid
# Now searching model: Integra
# Now searching model: Legend
# Now searching model: MDX
# Now searching model: MDX Sport Hybrid
# Now searching model: NSX
# Now searching model: RDX
# Now searching model: RL
# Now searching model: RLX
# Now searching model: RLX Sport Hybrid
# Now searching model: RSX
# Now searching model: TL
# Now searching model: TLX
# Now searching model: TSX
# Now searching model: ZDX
# Now searching model: Unknown
# Now searching: Alfa Romeo
# Now searching: Am General
# Now searching: American Motors
# Now searching: Aston Martin
# Now searching: Audi
# Now searching model: 100
# Now searching model: 5000
# Now searching model: A3
# Now searching model: A3 e-tron
# Now searching model: A4
# Now searching model: A4 allroad
# Now searching model: A5
# Now searching model: A6
# Now searching model: A7
# Now searching model: A8
# Now searching model: Cabriolet
# Now searching model: Q3
# Now searching model: Q5
# Now searching model: Q5 hybrid
# Now searching model: Q7
# Now searching model: Q8
# Now searching model: R8
# Now searching model: RS 3
# Now searching model: RS 4
# Now searching model: RS 5
# Now searching model: RS 7
# Now searching model: RS6
# Now searching model: S3
# Now searching model: S4
# Now searching model: S5
# Now searching model: S6
# Now searching model: S7
# Now searching model: S8
# Now searching model: SQ5
# Now searching model: TT
# Now searching model: TT RS
# Now searching model: TTS
# Now searching model: allroad
# Now searching model: Unknown
# Now searching: Austin-Healey
# Now searching: Avanti Motors
# Now searching: BMW
# Now searching model: 1 Series M
# Now searching model: 128
# Now searching model: 135
# Now searching model: 1600
# Now searching model: 2002
# Now searching model: 228
# Now searching model: 230
# Now searching model: 3.0
# Now searching model: 318
# Now searching model: 320
# Now searching model: 323
# Now searching model: 325
# Now searching model: 328
# Now searching model: 328 Gran Turismo
# Now searching model: 328d
# Now searching model: 330
# Now searching model: 330 Gran Turismo
# Now searching model: 330e
# Now searching model: 335
# Now searching model: 335 Gran Turismo
# Now searching model: 340
# Now searching model: 340 Gran Turismo
# Now searching model: 428
# Now searching model: 428 Gran Coupe
# Now searching model: 430
# Now searching model: 430 Gran Coupe
# Now searching model: 435
# Now searching model: 435 Gran Coupe
# Now searching model: 440
# Now searching model: 440 Gran Coupe
# Now searching model: 525
# Now searching model: 528
# Now searching model: 530
# Now searching model: 530e
# Now searching model: 535
# Now searching model: 535 Gran Turismo
# Now searching model: 535d
# Now searching model: 540
# Now searching model: 540d
# Now searching model: 545
# Now searching model: 550
# Now searching model: 550 Gran Turismo
# Now searching model: 633
# Now searching model: 635
# Now searching model: 640
# Now searching model: 640 Gran Coupe
# Now searching model: 640 Gran Turismo
# Now searching model: 645
# Now searching model: 650
# Now searching model: 650 Gran Coupe
# Now searching model: 735
# Now searching model: 740
# Now searching model: 740e
# Now searching model: 745
# Now searching model: 750
# Now searching model: 760
# Now searching model: 840
# Now searching model: 850
# Now searching model: ALPINA B6 Gran Coupe
# Now searching model: ALPINA B7
# Now searching model: ActiveHybrid 3
# Now searching model: ActiveHybrid 5
# Now searching model: ActiveHybrid 750
# Now searching model: ActiveHybrid X6
# Now searching model: L7
# Now searching model: M
# Now searching model: M2
# Now searching model: M235
# Now searching model: M240
# Now searching model: M3
# Now searching model: M4
# Now searching model: M5
# Now searching model: M550
# Now searching model: M6
# Now searching model: M6 Gran Coupe
# Now searching model: M760
# Now searching model: X1
# Now searching model: X2
# Now searching model: X3
# Now searching model: X4
# Now searching model: X5
# Now searching model: X5 M
# Now searching model: X5 eDrive
# Now searching model: X6
# Now searching model: X6 M
# Now searching model: Z3
# Now searching model: Z4
# Now searching model: Z4 M
# Now searching model: Z8
# Now searching model: i3
# Cannot search page: https://www.cars.com/for-sale/searchresults.action/?mdId=56067&mkId=20005&page=4&perPage=100&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true
# Now searching model: i8
# Now searching model: Unknown
# Now searching: Bentley
# Now searching: Bricklin
# Now searching: Bugatti
# Now searching: Buick
# Now searching model: Cascada
# Now searching model: Century
# Now searching model: Electra
# Now searching model: Electra 225
# Now searching model: Enclave
# Now searching model: Encore
# Now searching model: Envision
# Now searching model: Invicta
# Now searching model: LaCrosse
# Now searching model: LeSabre
# Now searching model: Lucerne
# Now searching model: Park Avenue
# Now searching model: Rainier
# Now searching model: Reatta
# Now searching model: Regal
# Now searching model: Regal Sportback
# Now searching model: Regal TourX
# Now searching model: Rendezvous
# Now searching model: Riviera
# Now searching model: Roadmaster
# Now searching model: Series 50
# Now searching model: Series 90
# Now searching model: Skyhawk
# Now searching model: Skylark
# Now searching model: Special
# Now searching model: Super
# Now searching model: Terraza
# Now searching model: Verano
# Now searching model: Wildcat
# Now searching model: Unknown
# Now searching: Cadillac
# Now searching model: ATS
# Now searching model: ATS-V
# Now searching model: Allante
# Now searching model: Brougham
# Now searching model: CT6
# Now searching model: CT6 PLUG-IN
# Now searching model: CTS
# Now searching model: CTS-V
# Now searching model: Catera
# Now searching model: DTS
# Now searching model: DeVille
# Now searching model: ELR
# Now searching model: Eldorado
# Now searching model: Escalade
# Now searching model: Escalade ESV
# Now searching model: Escalade EXT
# Now searching model: Escalade Hybrid
# Now searching model: Fleetwood
# Now searching model: SRX
# Now searching model: STS
# Now searching model: Series 60
# Now searching model: Series 62
# Now searching model: Seville
# Now searching model: XLR
# Now searching model: XT4
# Now searching model: XT5
# Now searching model: XTS
# Now searching model: Unknown
# Now searching: Chevrolet
# Now searching model: 1500
# Now searching model: 210
# Now searching model: 2500
# Now searching model: 3100
# Now searching model: 3500
# Now searching model: Astro
# Now searching model: Avalanche
# Now searching model: Aveo
# Now searching model: Bel Air
# Now searching model: Beretta
# Now searching model: Biscayne
# Now searching model: Blazer
# Now searching model: Bolt EV
# Now searching model: C10/K10
# Now searching model: C20/K20
# Now searching model: C30/K30
# Now searching model: Camaro
# Now searching model: Caprice
# Now searching model: Caprice Classic
# Now searching model: Captiva Sport
# Now searching model: Cavalier
# Now searching model: Celebrity
# Now searching model: Chevelle
# Now searching model: Chevette
# Now searching model: Chevy II
# Now searching model: Citation
# Now searching model: City Express
# Now searching model: Classic
# Now searching model: Cobalt
# Now searching model: Colorado
# Now searching model: Confederate
# Now searching model: Corsica
# Now searching model: Corvair
# Now searching model: Corvette
# Now searching model: Corvette Stingray
# Now searching model: Cruze
# Now searching model: Cruze Limited
# Now searching model: El Camino
# Now searching model: Equinox
# Now searching model: Express 1500
# Now searching model: Express 2500
# Now searching model: Express 3500
# Now searching model: Fleetline
# Now searching model: Fleetmaster
# Now searching model: HHR
# Now searching model: Impala
# Now searching model: Impala Limited
# Now searching model: Independence
# Now searching model: Laguna S-3
# Now searching model: Lumina
# Now searching model: Lumina APV
# Now searching model: Luv
# Now searching model: Malibu
# Now searching model: Malibu Classic
# Now searching model: Malibu Hybrid
# Now searching model: Malibu Limited
# Now searching model: Malibu Maxx
# Now searching model: Master
# Now searching model: Master 85
# Now searching model: Master Deluxe
# Now searching model: Metro
# Now searching model: Monte Carlo
# Now searching model: Nova
# Now searching model: Pickup
# Now searching model: Prizm
# Now searching model: S-10
# Now searching model: S-10 Blazer
# Now searching model: SS
# Now searching model: SSR
# Now searching model: Sedan Delivery
# Now searching model: Silverado 1500
# Now searching model: Silverado 1500 Hybrid
# Now searching model: Silverado 1500 LD
# Now searching model: Silverado 2500
# Now searching model: Silverado 3500
# Now searching model: Sonic
# Now searching model: Spark
# Now searching model: Spark EV
# Now searching model: Sportvan
# Now searching model: Standard
# Now searching model: Styleline
# Now searching model: Suburban
# Now searching model: Superior
# Now searching model: Tahoe
# Now searching model: Tahoe Hybrid
# Now searching model: Tracker
# Now searching model: TrailBlazer
# Now searching model: TrailBlazer EXT
# Now searching model: Traverse
# Cannot search page: https://www.cars.com/for-sale/searchresults.action/?mdId=22296&mkId=20053&page=100&perPage=100&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true
# Now searching model: Trax
# Now searching model: Uplander
# Now searching model: V30
# Now searching model: Van
# Now searching model: Vega
# Now searching model: Venture
# Now searching model: Volt
# Now searching model: Unknown
# Now searching: Chrysler
# Now searching model: 200
# Now searching model: 300
# Now searching model: 300C
# Now searching model: 300M
# Now searching model: Airflow
# Now searching model: Aspen
# Now searching model: Aspen Hybrid
# Now searching model: Cirrus
# Now searching model: Concorde
# Now searching model: Cordoba
# Now searching model: Crossfire
# Now searching model: Crown Imperial
# Now searching model: Fifth Avenue
# Now searching model: Imperial
# Now searching model: LHS
# Now searching model: LeBaron
# Now searching model: New Yorker
# Now searching model: Newport
# Now searching model: PT Cruiser
# Now searching model: Pacifica
# Now searching model: Pacifica Hybrid
# Now searching model: Prowler
# Now searching model: Sebring
# Now searching model: TC by Maserati
# Now searching model: Town & Country
# Now searching model: Voyager
# Now searching model: Windsor
# Now searching model: Unknown
# Now searching: Citroen
# Now searching: Daewoo
# Now searching: Datsun
# Now searching: DeTomaso
# Now searching: Delorean
# Now searching: Dodge
# Now searching model: Aspen
# Now searching model: Avenger
# Now searching model: Caliber
# Now searching model: Caravan
# Now searching model: Challenger
# Now searching model: Charger
# Now searching model: Coronet
# Now searching model: Dakota
# Now searching model: Dart
# Now searching model: Daytona
# Now searching model: Durango
# Now searching model: Durango Hybrid
# Now searching model: Dynasty
# Now searching model: Grand Caravan
# Now searching model: Intrepid
# Now searching model: Journey
# Now searching model: Magnum
# Now searching model: Monaco
# Now searching model: Neon
# Now searching model: Nitro
# Now searching model: Omni
# Now searching model: Panel
# Now searching model: Pickup
# Now searching model: Polara
# Now searching model: Ram 1500
# Now searching model: Ram 2500
# Now searching model: Ram 3500
# Now searching model: Ram 50
# Now searching model: Ram Van
# Now searching model: Ram Wagon
# Now searching model: Ramcharger
# Now searching model: Royal
# Now searching model: SRT Viper
# Now searching model: Shadow
# Now searching model: Sprinter
# Now searching model: Stealth
# Now searching model: Stratus
# Now searching model: Super Bee
# Now searching model: Van
# Now searching model: Viper
# Now searching model: W250
# Now searching model: Wayfarer
# Now searching model: Unknown
# Now searching: Eagle
# Now searching: Edsel
# Now searching: FIAT
# Now searching: Ferrari
# Now searching: Fisker
# Now searching: Ford
# Now searching model: Aerostar
# Now searching model: Bronco
# Now searching model: Bronco II
# Now searching model: C-Max Energi
# Now searching model: C-Max Hybrid
# Now searching model: Club Wagon
# Now searching model: Contour
# Now searching model: Coupe
# Now searching model: Courier
# Now searching model: Crestline
# Now searching model: Crown Victoria
# Now searching model: Custom
# Now searching model: Custom Deluxe
# Now searching model: Customline
# Now searching model: Deluxe
# Now searching model: E150
# Now searching model: E250
# Now searching model: E350
# Now searching model: E350 Super Duty
# Now searching model: EcoSport
# Now searching model: Edge
# Now searching model: Escape
# Now searching model: Escape Hybrid
# Now searching model: Escort
# Now searching model: Excursion
# Now searching model: Expedition
# Now searching model: Expedition EL
# Now searching model: Expedition Max
# Now searching model: Explorer
# Now searching model: Explorer Sport
# Now searching model: Explorer Sport Trac
# Now searching model: F-150
# Now searching model: F-250
# Now searching model: F-350
# Now searching model: F-450
# Now searching model: F100
# Now searching model: Fairlane
# Now searching model: Fairlane 500
# Now searching model: Fairmont
# Now searching model: Falcon
# Now searching model: Festiva
# Now searching model: Fiesta
# Now searching model: Five Hundred
# Now searching model: Flex
# Now searching model: Focus
# Now searching model: Focus Electric
# Now searching model: Focus RS
# Now searching model: Focus ST
# Now searching model: Freestar
# Now searching model: Freestyle
# Now searching model: Fusion
# Now searching model: Fusion Energi
# Now searching model: Fusion Hybrid
# Now searching model: GT
# Now searching model: Galaxie
# Now searching model: Galaxie 500
# Now searching model: Galaxie 500 XL
# Now searching model: Granada
# Now searching model: LTD
# Now searching model: Maverick
# Now searching model: Model 68
# Now searching model: Model 79A
# Now searching model: Model A
# Now searching model: Model B
# Now searching model: Model T
# Now searching model: Mustang
# Now searching model: Mustang Shelby GT
# Now searching model: Pickup
# Now searching model: Pinto
# Now searching model: Probe
# Now searching model: Ranch
# Now searching model: Ranchero
# Now searching model: Ranger
# Now searching model: Roadster
# Now searching model: Sedan Delivery
# Now searching model: Sedan Police Interceptor
# Now searching model: Shelby GT350
# Now searching model: Shelby GT500
# Now searching model: Sunliner
# Now searching model: Super Deluxe
# Now searching model: Taurus
# Now searching model: Taurus X
# Now searching model: Tempo
# Now searching model: Thunderbird
# Now searching model: Torino
# Now searching model: Torino GT
# Now searching model: Transit Connect
# Now searching model: Transit-150
# Now searching model: Transit-250
# Now searching model: Transit-350
# Now searching model: Utility Police Interceptor
# Now searching model: Van
# Now searching model: Windstar
# Now searching model: ZX2
# Now searching model: Unknown
# Now searching: GMC
# Now searching model: 1500
# Now searching model: 2500
# Now searching model: 3500
# Now searching model: Acadia
# Now searching model: Acadia Limited
# Now searching model: Caballero
# Now searching model: Canyon
# Now searching model: Envoy
# Now searching model: Envoy XL
# Now searching model: Envoy XUV
# Now searching model: Jimmy
# Now searching model: Pickup
# Now searching model: Rally
# Now searching model: S-15 Jimmy
# Now searching model: S-15 Pickup
# Now searching model: Safari
# Now searching model: Savana 1500
# Now searching model: Savana 2500
# Now searching model: Savana 3500
# Now searching model: Sierra 1500
# Now searching model: Sierra 1500 Hybrid
# Now searching model: Sierra 1500 Limited
# Now searching model: Sierra 2500
# Now searching model: Sierra 3500
# Now searching model: Sonoma
# Now searching model: Sprint
# Now searching model: Suburban
# Now searching model: Terrain
# Now searching model: Vandura
# Now searching model: Yukon
# Now searching model: Yukon Hybrid
# Now searching model: Yukon XL
# Now searching model: Unknown
# Now searching: Genesis
# Now searching: Geo
# Now searching: Honda
# Now searching model: Accord
# Now searching model: Accord Crosstour
# Now searching model: Accord Hybrid
# Now searching model: Accord Plug-In Hybrid
# Now searching model: CR-V
# Now searching model: CR-Z
# Now searching model: CRX
# Now searching model: Civic
# Now searching model: Civic Hybrid
# Now searching model: Civic Si
# Now searching model: Civic Type R
# Now searching model: Clarity Plug-In Hybrid
# Now searching model: Crosstour
# Now searching model: Element
# Now searching model: Fit
# Now searching model: HR-V
# Now searching model: Insight
# Now searching model: Odyssey
# Now searching model: Passport
# Now searching model: Pilot
# Now searching model: Prelude
# Now searching model: Ridgeline
# Now searching model: S2000
# Now searching model: del Sol
# Now searching model: Unknown
# Now searching: Hudson
# Now searching: Hummer
# Now searching: Hyundai
# Now searching model: Accent
# Now searching model: Azera
# Now searching model: Elantra
# Cannot search page: https://www.cars.com/for-sale/searchresults.action/?mdId=21053&mkId=20064&page=42&perPage=100&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true
# Now searching model: Elantra GT
# Now searching model: Elantra Touring
# Now searching model: Entourage
# Now searching model: Equus
# Now searching model: Excel
# Now searching model: Genesis
# Now searching model: Genesis Coupe
# Now searching model: Ioniq EV
# Now searching model: Ioniq Hybrid
# Now searching model: Ioniq Plug-In Hybrid
# Now searching model: Kona
# Now searching model: Santa Fe
# Now searching model: Santa Fe Sport
# Now searching model: Santa Fe XL
# Now searching model: Sonata
# Now searching model: Sonata Hybrid
# Now searching model: Sonata Plug-In Hybrid
# Now searching model: Tiburon
# Now searching model: Tucson
# Now searching model: Veloster
# Now searching model: Veracruz
# Now searching model: XG300
# Now searching model: XG350
# Now searching model: Unknown
# Now searching: INFINITI
# Now searching model: EX35
# Now searching model: EX37
# Now searching model: FX35
# Now searching model: FX37
# Now searching model: FX45
# Now searching model: FX50
# Now searching model: G20
# Now searching model: G25
# Now searching model: G25x
# Now searching model: G35
# Now searching model: G35x
# Now searching model: G37
# Now searching model: G37x
# Now searching model: I30
# Now searching model: I35
# Now searching model: IPL G
# Now searching model: J30
# Now searching model: JX35
# Now searching model: M30
# Now searching model: M35
# Now searching model: M35h
# Now searching model: M35x
# Now searching model: M37
# Now searching model: M37x
# Now searching model: M45
# Now searching model: M45x
# Now searching model: M56
# Now searching model: M56x
# Now searching model: Q40
# Now searching model: Q45
# Now searching model: Q50
# Now searching model: Q50 Hybrid
# Now searching model: Q60
# Now searching model: Q60 IPL
# Now searching model: Q70
# Now searching model: Q70L
# Now searching model: Q70h
# Now searching model: QX30
# Now searching model: QX4
# Now searching model: QX50
# Now searching model: QX56
# Now searching model: QX60
# Now searching model: QX60 Hybrid
# Now searching model: QX70
# Now searching model: QX80
# Now searching model: Unknown
# Now searching: International
# Now searching: Isuzu
# Now searching: Jaguar
# Now searching model: E-PACE
# Now searching model: F-PACE
# Now searching model: F-TYPE
# Now searching model: I-PACE
# Now searching model: Mark II
# Now searching model: S-Type
# Now searching model: Super V8
# Now searching model: Vanden Plas
# Now searching model: X-Type
# Now searching model: XE
# Now searching model: XF
# Now searching model: XJ
# Now searching model: XJ12
# Now searching model: XJ6
# Now searching model: XJ8
# Now searching model: XJR
# Now searching model: XJS
# Now searching model: XK
# Now searching model: XK 120
# Now searching model: XK8
# Now searching model: XKE
# Now searching model: XKR
# Now searching model: Unknown
# Now searching: Jeep
# Now searching model: CJ
# Now searching model: CJ-5
# Now searching model: CJ-7
# Now searching model: Cherokee
# Now searching model: Comanche
# Now searching model: Commander
# Now searching model: Commando
# Now searching model: Compass
# Now searching model: Grand Cherokee
# Now searching model: Grand Wagoneer
# Now searching model: Liberty
# Now searching model: New Compass
# Now searching model: Patriot
# Now searching model: Renegade
# Now searching model: Scrambler
# Now searching model: Wagoneer
# Now searching model: Wrangler
# Now searching model: Wrangler JK
# Now searching model: Wrangler JK Unlimited
# Now searching model: Wrangler Unlimited
# Now searching model: Unknown
# Now searching: Jensen
# Now searching: Karma
# Now searching: Kia
# Now searching model: Amanti
# Now searching model: Borrego
# Now searching model: Cadenza
# Now searching model: Forte
# Now searching model: Forte Koup
# Now searching model: K900
# Now searching model: Niro
# Now searching model: Niro Plug-In Hybrid
# Now searching model: Optima
# Now searching model: Optima Hybrid
# Now searching model: Optima Plug-In Hybrid
# Now searching model: Rio
# Now searching model: Rio5
# Now searching model: Rondo
# Now searching model: Sedona
# Now searching model: Sephia
# Now searching model: Sorento
# Now searching model: Soul
# Now searching model: Soul EV
# Now searching model: Spectra
# Now searching model: Spectra5
# Now searching model: Sportage
# Now searching model: Stinger
# Now searching model: Unknown
# Now searching: Koenigsegg
# Now searching: Lamborghini
# Now searching: Land Rover
# Now searching model: Defender
# Now searching model: Discovery
# Now searching model: Discovery Sport
# Now searching model: Freelander
# Now searching model: LR2
# Now searching model: LR3
# Now searching model: LR4
# Now searching model: Range Rover
# Now searching model: Range Rover Evoque
# Now searching model: Range Rover Sport
# Now searching model: Range Rover Velar
# Now searching model: Series II
# Now searching model: Series III
# Now searching model: Unknown
# Now searching: Lexus
# Now searching model: CT 200h
# Now searching model: ES 250
# Now searching model: ES 300
# Now searching model: ES 300h
# Now searching model: ES 330
# Now searching model: ES 350
# Now searching model: GS 200t
# Now searching model: GS 300
# Now searching model: GS 350
# Now searching model: GS 400
# Now searching model: GS 430
# Now searching model: GS 450h
# Now searching model: GS 460
# Now searching model: GS F
# Now searching model: GX 460
# Now searching model: GX 470
# Now searching model: HS 250h
# Now searching model: IS 200t
# Now searching model: IS 250
# Now searching model: IS 250C
# Now searching model: IS 300
# Now searching model: IS 350
# Now searching model: IS 350C
# Now searching model: IS-F
# Now searching model: LC 500
# Now searching model: LC 500h
# Now searching model: LFA
# Now searching model: LS 400
# Now searching model: LS 430
# Now searching model: LS 460
# Now searching model: LS 500
# Now searching model: LS 500h
# Now searching model: LS 600h L
# Now searching model: LX 450
# Now searching model: LX 470
# Now searching model: LX 570
# Now searching model: NX 200t
# Now searching model: NX 300
# Now searching model: NX 300h
# Now searching model: RC 200t
# Now searching model: RC 300
# Now searching model: RC 350
# Now searching model: RC F
# Now searching model: RX 300
# Now searching model: RX 330
# Now searching model: RX 350
# Now searching model: RX 350L
# Now searching model: RX 400h
# Now searching model: RX 450h
# Now searching model: RX 450hL
# Now searching model: SC 300
# Now searching model: SC 400
# Now searching model: SC 430
# Now searching model: UX 200
# Now searching model: Unknown
# Now searching: Lincoln
# Now searching model: Aviator
# Now searching model: Blackwood
# Now searching model: Capri
# Now searching model: Continental
# Now searching model: LS
# Now searching model: MKC
# Now searching model: MKS
# Now searching model: MKT
# Now searching model: MKX
# Now searching model: MKZ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0a5b94ef1d04> in <module>()
# ----> 1 launch_search()
#
# <ipython-input-6-a23ddbcf4b3c> in launch_search()
#      48                 html = bs4.BeautifulSoup(response.text, "lxml")
#      49                 list_of_cars = []
# ---> 50                 launch_search_given_id(url_tmp, list_of_cars, make_id, md_id)
#      51                 df_car = pd.DataFrame(list_of_cars, columns=['Name', 'Mileage', 'Price'])
#      52                 file_name = '(New)' + brand + "-" + md + '.csv'
#
# <ipython-input-6-a23ddbcf4b3c> in launch_search_given_id(url, lst, make_id, md_id)
#      12             grab_data_from_given_url(url_head + 'mkId=' + make_id + "&" + "page="                                          + str(page_num) + url_tail, lst)
#      13         else:
# ---> 14             grab_data_from_given_url(url_head + "mdId=" + md_id + "&" + 'mkId=' + make_id + "&" + "page="                                          + str(page_num) + url_tail, lst)
#      15
#      16 def launch_search():
#
# <ipython-input-3-dd00b5f419a0> in grab_data_from_given_url(url, lst)
#       1 def grab_data_from_given_url(url, lst):
#       2     response = requests.get(url)
# ----> 3     html = bs4.BeautifulSoup(response.text, "lxml")
#       4     tmp_lst = html.find_all("div", id = "srp-listing-rows-container")
#       5     if(len(tmp_lst) == 0):
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     248         try:
#     249             self.parser = self.parser_for(encoding)
# --> 250             self.parser.feed(markup)
#     251             self.parser.close()
#     252         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:114563)()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:114436)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:131282)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:131025)()
#
# src/lxml/lxml.etree.pyx in lxml.etree._ExceptionContext._raise_if_stored (src/lxml/lxml.etree.c:12167)()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs (src/lxml/lxml.etree.c:123503)()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart (src/lxml/lxml.etree.c:123700)()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart (src/lxml/lxml.etree.c:130022)()
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/builder/_lxml.py in start(self, name, attrs, nsmap)
#     143         self.nsmaps = [self.DEFAULT_NSMAPS]
#     144
# --> 145     def start(self, name, attrs, nsmap={}):
#     146         # Make sure attrs is a mutable dict--lxml may send an immutable dictproxy.
#     147         attrs = dict(attrs)
#
# KeyboardInterrupt:

# %%
s = 'as'
s.replace('a', ' ')
# Out:
# ' s'

# %%
s
# Out:
# ' s'

# %%
html.find_all('input', attrs={"name": "mkId"})[0]['value']
# Out:
# '20046'

# %%
html.find_all('span', attrs={'class':"count"})[0]
# Out:
# <span class="count">1,908,046</span>

# %%
html.find_all("href", class_ = "js-last-page")
# Out:
# []

# %%
 html.find_all('input', attrs={"name": "mkId"})[0].parent.label.text.strip()

# %%
html.find_all('span', attrs={'class':"count"})[0].text.replace(',', '')
# Out:
# '1905220'

# %%
https://www.cars.com/for-sale/searchresults.action/?mdId=21138&mkId=20015&
    mlgId=28863&page=1&perPage=20&rd=99999&searchSource=GN_REFINEMENT&
    shippable-dealers-checkbox=true&showMore=true&sort=relevance&stkTypId=28881&zc=92093&localVehicles=false

# %%
url_head = "https://www.cars.com/for-sale/searchresults.action/?page="
url_tail = "&perPage=100&rd=99999&searchSource=PAGINATION&shippable-dealers-checkbox=true&showMore=true&sort=relevance&stkTypId=28881&zc=92093&localVehicles=false"


car_list = []
for i in range(1, 2):
    print(i)
    response = requests.get(url_head + str(i) + url_tail)
    html = bs4.BeautifulSoup(response.text, "lxml")
    container = html.find_all("div", id = "srp-listing-rows-container")[0]
    for child in container.children:
        car = []
        if type(child) is not bs4.element.NavigableString and child.name == 'div':
            if child.has_attr('class') and child.a:
                for ch in child.a.div.children:
                    if type(ch) is bs4.element.Tag and ch.has_attr('class') and ch['class'][0] == 'listing-row__details':
                        for item in ch.find_all('span'):
                            if type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__price':
                                car.append(item.text.strip())
                        car.append(ch.h2.text.strip())
                        for small_part in ch.children:
                            if small_part is bs4.element.Tag and small_part.has_attr('class'):
                                if small_part['class'][0] == 'listing-row__stocktype':
                                    car['Status'] = small_part.text
        
        if len(car):
            car_list.append(car)
        
    
            
df_cars = pd.DataFrame(car_list ,columns=['Name','Price'],dtype=str)
# Out:
# 1

# %%
df_car
# Out:
#                         Name    Price      Mileage
# 0          2016 Ford Focus S   $9,981   31,511 mi.
# 1   2018 Ford Focus Titanium  $13,981   16,862 mi.
# 2         2014 Ford Focus SE   $8,435   77,201 mi.
# 3         2012 Ford Focus SE   $5,999  100,398 mi.
# 4         2013 Ford Focus SE   $8,995   31,640 mi.
# 5   2016 Ford Focus Titanium  $14,965   18,085 mi.
# 6         2013 Ford Focus SE   $7,900   72,619 mi.
# 7         2013 Ford Focus SE   $7,993   63,102 mi.
# 8         2013 Ford Focus SE   $6,595  129,096 mi.
# 9          2015 Ford Focus S   $8,990   30,944 mi.
# 10         2016 Ford Focus S   $9,978   31,177 mi.
# 11  2015 Ford Focus Titanium  $13,595   16,758 mi.
# 12         2014 Ford Focus S   $6,984   59,704 mi.
# 13  2015 Ford Focus Titanium  $14,490    8,161 mi.
# 14        2012 Ford Focus SE   $7,373  100,585 mi.
# 15        2012 Ford Focus SE   $5,395  114,431 mi.
# 16        2014 Ford Focus SE   $8,900   80,512 mi.
# 17        2015 Ford Focus SE   $9,999   66,105 mi.
# 18        2013 Ford Focus SE   $5,996   96,676 mi.
# 19       2012 Ford Focus SEL   $6,977   86,582 mi.

# %%
def grab_data_from_given_url(url, lst):
    response = requests.get(url)
    html = bs4.BeautifulSoup(response.text, "lxml")
    container = html.find_all("div", id = "srp-listing-rows-container")[0]
    for child in container.children:
        car = {}
        if type(child) is not bs4.element.NavigableString and child.name == 'div':
            if child.has_attr('class') and child.a:
                for ch in child.a.div.children:
                    if type(ch) is bs4.element.Tag and ch.has_attr('class') and ch['class'][0] == 'listing-row__details':
                        car['Name'] = ch.h2.text.strip()
                        for item in ch.find_all('span'):
                            if type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__mileage':
                                car['Mileage'] = item.text.strip()
                            elif type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__price':
                                car['Price'] = item.text.strip()
                        
        if len(car) > 0:
            lst.append(car)

# %%
car_lst = []
grab_data_from_given_url('https://www.cars.com/for-sale/searchresults.action/?mdId=21138&page=1&perPage=20&rd=99999&searchSource=GN_REFINEMENT&showMore=true&sort=relevance&stkTypId=28881&zc=92093&userSetIxt=true', car_lst)
df_car = pd.DataFrame(car_lst, columns=['Name', 'Mileage', 'Price'])
car_lst
# Out:
# $9,981
# $13,981
# $8,435
# $5,999
# $8,995
# $14,965
# $7,900
# $7,993
# $6,595
# $8,990
# $9,978
# $13,595
# $6,984
# $14,490
# $7,373
# $5,395
# $8,900
# $9,999
# $5,996
# $6,977
# [{'Mileage': '31,511 mi.', 'Name': '2016 Ford Focus S', 'Price': '$9,981'},
#  {'Mileage': '16,862 mi.',
#   'Name': '2018 Ford Focus Titanium',
#   'Price': '$13,981'},
#  {'Mileage': '77,201 mi.', 'Name': '2014 Ford Focus SE', 'Price': '$8,435'},
#  {'Mileage': '100,398 mi.', 'Name': '2012 Ford Focus SE', 'Price': '$5,999'},
#  {'Mileage': '31,640 mi.', 'Name': '2013 Ford Focus SE', 'Price': '$8,995'},
#  {'Mileage': '18,085 mi.',
#   'Name': '2016 Ford Focus Titanium',
#   'Price': '$14,965'},
#  {'Mileage': '72,619 mi.', 'Name': '2013 Ford Focus SE', 'Price': '$7,900'},
#  {'Mileage': '63,102 mi.', 'Name': '2013 Ford Focus SE', 'Price': '$7,993'},
#  {'Mileage': '129,096 mi.', 'Name': '2013 Ford Focus SE', 'Price': '$6,595'},
#  {'Mileage': '30,944 mi.', 'Name': '2015 Ford Focus S', 'Price': '$8,990'},
#  {'Mileage': '31,177 mi.', 'Name': '2016 Ford Focus S', 'Price': '$9,978'},
#  {'Mileage': '16,758 mi.',
#   'Name': '2015 Ford Focus Titanium',
#   'Price': '$13,595'},
#  {'Mileage': '59,704 mi.', 'Name': '2014 Ford Focus S', 'Price': '$6,984'},
#  {'Mileage': '8,161 mi.',
#   'Name': '2015 Ford Focus Titanium',
#   'Price': '$14,490'},
#  {'Mileage': '100,585 mi.', 'Name': '2012 Ford Focus SE', 'Price': '$7,373'},
#  {'Mileage': '114,431 mi.', 'Name': '2012 Ford Focus SE', 'Price': '$5,395'},
#  {'Mileage': '80,512 mi.', 'Name': '2014 Ford Focus SE', 'Price': '$8,900'},
#  {'Mileage': '66,105 mi.', 'Name': '2015 Ford Focus SE', 'Price': '$9,999'},
#  {'Mileage': '96,676 mi.', 'Name': '2013 Ford Focus SE', 'Price': '$5,996'},
#  {'Mileage': '86,582 mi.', 'Name': '2012 Ford Focus SEL', 'Price': '$6,977'}]

# %%
df_car
# Out:
#                         Name    Price      Mileage
# 0          2016 Ford Focus S   $9,981   31,511 mi.
# 1   2018 Ford Focus Titanium  $13,981   16,862 mi.
# 2         2014 Ford Focus SE   $8,435   77,201 mi.
# 3         2012 Ford Focus SE   $5,999  100,398 mi.
# 4         2013 Ford Focus SE   $8,995   31,640 mi.
# 5   2016 Ford Focus Titanium  $14,965   18,085 mi.
# 6         2013 Ford Focus SE   $7,900   72,619 mi.
# 7         2013 Ford Focus SE   $7,993   63,102 mi.
# 8         2013 Ford Focus SE   $6,595  129,096 mi.
# 9          2015 Ford Focus S   $8,990   30,944 mi.
# 10         2016 Ford Focus S   $9,978   31,177 mi.
# 11  2015 Ford Focus Titanium  $13,595   16,758 mi.
# 12         2014 Ford Focus S   $6,984   59,704 mi.
# 13  2015 Ford Focus Titanium  $14,490    8,161 mi.
# 14        2012 Ford Focus SE   $7,373  100,585 mi.
# 15        2012 Ford Focus SE   $5,395  114,431 mi.
# 16        2014 Ford Focus SE   $8,900   80,512 mi.
# 17        2015 Ford Focus SE   $9,999   66,105 mi.
# 18        2013 Ford Focus SE   $5,996   96,676 mi.
# 19       2012 Ford Focus SEL   $6,977   86,582 mi.

# %%
url_head = "https://www.cars.com/for-sale/searchresults.action/?page="
url_tail = "&perPage=20&rd=99999&searchSource=PAGINATION&shippable-dealers-checkbox=true&showMore=true&sort=relevance&stkTypId=28881&zc=92093&localVehicles=false"


car_list = []
for i in range(1, 2):
    response = requests.get(url_head + str(i) + url_tail)
    html = bs4.BeautifulSoup(response.text, "lxml")
    container = html.find_all("div", id = "srp-listing-rows-container")[0]
    car_count = 0
    for child in container.children:
        if car_count == 20:
            break
        car = []
        if type(child) is not bs4.element.NavigableString and child.name == 'div':
            if child.has_attr('class'):
                
                for ch in child.a.div.children:
                    if type(ch) is bs4.element.Tag and ch.has_attr('class') and ch['class'][0] == 'listing-row__details':
                        car.append(ch.h2.text.strip())
                        
                        for item in ch.find_all('span'):
                            if type(item) is bs4.element.Tag and item.has_attr('class') and item['class'][0] == 'listing-row__price':
                                car.append(item.text.strip())
#                                 print(type(item.text))
                        
                        for small_part in ch.children:
                            if small_part is bs4.element.Tag and small_part.has_attr('class'):
                                if small_part['class'][0] == 'listing-row__stocktype':
                                    car['Status'] = small_part.text
        
#         if len(car):
#             car_list.append(car)
#             car_count += 1
#         print(car_list)

df_cars = pd.DataFrame(car_list ,columns=['Name','Price'],dtype=str)
